# %%
#import dependencies
import pandas as pd

student_data_to_load = "Resources/students_complete.csv"

student_data_df = pd.read_csv(student_data_to_load)
student_data_df.head()

#we need to get all the students' names in a separate file so we don't affect the DataFrame.
# Put the student names in a list.
student_names = student_data_df["student_name"].tolist()
student_names
# Split the student name and determine the length of the split name.
for name in student_names:
    print(name.split(), len(name.split()))

# %%
name = "Mrs. Linda Santiago"
print(name.split())

# %%
#import dependencies
import pandas as pd

student_data_to_load = "Resources/students_complete.csv"

student_data_df = pd.read_csv(student_data_to_load)
student_data_df.head()

#we need to get all the students' names in a separate file so we don't affect the DataFrame.
# Put the student names in a list.
student_names = student_data_df["student_name"].tolist()
student_names
# Split the student name and determine the length of the split name.
for name in student_names:
    print(name.split(), len(name.split()))

# %%
#import dependencies
import pandas as pd

student_data_to_load = "Resources/students_complete.csv"

student_data_df = pd.read_csv(student_data_to_load)
student_data_df.head()

#we need to get all the students' names in a separate file so we don't affect the DataFrame.
# Put the student names in a list.
student_names = student_data_df["student_name"].tolist()
student_names
# Create a new list and use it for the for loop to iterate through the list.
students_to_fix = []

# Use an if statement to check the length of the name.
# If the name is greater than or equal to "3", add the name to the list.

for name in student_names:
    if len(name.split()) >= 3:
        students_to_fix.append(name)

# Get the length of the students whose names are greater than or equal to "3".
len(students_to_fix)

# %%
#import dependencies
import pandas as pd

student_data_to_load = "Resources/students_complete.csv"

student_data_df = pd.read_csv(student_data_to_load)
student_data_df.head()

#we need to get all the students' names in a separate file so we don't affect the DataFrame.
# Put the student names in a list.
student_names = student_data_df["student_name"].tolist()
student_names
# Create a new list and use it for the for loop to iterate through the list.
students_to_fix = []

# Use an if statement to check the length of the name.
# If the name is greater than or equal to "3", add the name to the list.

for name in student_names:
    if len(name.split()) >= 3:
        students_to_fix.append(name)

# Get the length of the students whose names are greater than or equal to "3".
len(students_to_fix)

# Add the prefixes less than or equal to 4 to a new list.
prefixes = []
for name in students_to_fix:
    if len(name.split()[0]) <= 4:
        prefixes.append(name.split()[0])

print(prefixes)

# %%
#import dependencies
import pandas as pd

student_data_to_load = "Resources/students_complete.csv"

student_data_df = pd.read_csv(student_data_to_load)
student_data_df.head()

#we need to get all the students' names in a separate file so we don't affect the DataFrame.
# Put the student names in a list.
student_names = student_data_df["student_name"].tolist()
student_names
# Create a new list and use it for the for loop to iterate through the list.
students_to_fix = []

# Use an if statement to check the length of the name.
# If the name is greater than or equal to "3", add the name to the list.

for name in student_names:
    if len(name.split()) >= 3:
        students_to_fix.append(name)

# Get the length of the students whose names are greater than or equal to "3".
len(students_to_fix)

# Add the suffixes less than or equal to 3 to a new list.
suffixes = []
for name in students_to_fix:
    if len(name.split()[-1]) <= 3:
        suffixes.append(name.split()[-1])

print(suffixes)

# %%
#import dependencies  PREFIXES
import pandas as pd

student_data_to_load = "Resources/students_complete.csv"

student_data_df = pd.read_csv(student_data_to_load)
student_data_df.head()

#we need to get all the students' names in a separate file so we don't affect the DataFrame.
# Put the student names in a list.
student_names = student_data_df["student_name"].tolist()
student_names
# Create a new list and use it for the for loop to iterate through the list.
students_to_fix = []

# Use an if statement to check the length of the name.
# If the name is greater than or equal to "3", add the name to the list.

for name in student_names:
    if len(name.split()) >= 3:
        students_to_fix.append(name)

# Get the length of the students whose names are greater than or equal to "3".
len(students_to_fix)

# Add the prefixes less than or equal to 4 to a new list.
prefixes = []
for name in students_to_fix:
    if len(name.split()[0]) <= 4:
        prefixes.append(name.split()[0])

        # Get the unique items in the "prefixes" list.
set(prefixes)

print(prefixes)

# %%
#import dependencies - SUFFIXES - how to find suffixes and how to replace them
import pandas as pd

student_data_to_load = "Resources/students_complete.csv"

student_data_df = pd.read_csv(student_data_to_load)
student_data_df.head()

#we need to get all the students' names in a separate file so we don't affect the DataFrame.
# Put the student names in a list.
student_names = student_data_df["student_name"].tolist()
student_names
# Create a new list and use it for the for loop to iterate through the list.
students_to_fix = []

# Use an if statement to check the length of the name.
# If the name is greater than or equal to "3", add the name to the list.

for name in student_names:
    if len(name.split()) >= 3:
        students_to_fix.append(name)

# Get the length of the students whose names are greater than or equal to "3".
len(students_to_fix)

# Add the suffixes less than or equal to 3 to a new list.
suffixes = []
for name in students_to_fix:
    if len(name.split()[-1]) <= 3:
        suffixes.append(name.split()[-1])

# Get the unique items in the "suffixes" list.
set(suffixes)

print(suffixes)

# %%
#import dependencies  PREFIXES - how to find which prefixes and how to replace them
import pandas as pd

student_data_to_load = "Resources/students_complete.csv"

student_data_df = pd.read_csv(student_data_to_load)
student_data_df.head()

#we need to get all the students' names in a separate file so we don't affect the DataFrame.
# Put the student names in a list.
student_names = student_data_df["student_name"].tolist()
student_names
# Create a new list and use it for the for loop to iterate through the list.
students_to_fix = []

# Use an if statement to check the length of the name.
# If the name is greater than or equal to "3", add the name to the list.

for name in student_names:
    if len(name.split()) >= 3:
        students_to_fix.append(name)

# Get the length of the students whose names are greater than or equal to "3".
len(students_to_fix)

# Add the prefixes less than or equal to 4 to a new list.
prefixes = []
for name in students_to_fix:
    if len(name.split()[0]) <= 4:
        prefixes.append(name.split()[0])

#Get the unique items in the "prefixes" list.
set(prefixes)

# Replace prefixes for the list from the student names. This only works for one at a time
for name in students_to_fix:
    print(name.replace("Mrs.", ""))
# Out:
# Dr. Richard Scott
# Dr. Jordan Carson
# Madeline Snyder MD
# Mr. Dylan Taylor MD
# Dr. Scott Gill
# Miss Madison Everett
# Virginia Ramirez MD
# Joseph Morales III
# Angela Perkins DVM
# Heather Allen MD
# Luke Lowery MD
# Dr. Larry Hines
# Emily Cardenas MD
#  Elizabeth Espinoza DDS
#  Lisa Becker
# Mr. Travis Young
# Paula Fernandez DVM
# Dr. Xavier Bell II
# Andrew Hanson MD
# Mr. Roberto Wright MD
# Mr. Dale Miller
# Mary Gonzalez DDS
#  Cindy Brown
# James White MD
# Donald Gill DDS
#  Catherine Williams MD
# Ashley Caldwell MD
# Mr. Jared Campbell
# Michael Moreno PhD
# Tara Parker MD
# Shawn Williams DVM
# Dr. Alicia Martinez
# Mr. Timothy Anderson
#  Paula Lee
# Mr. Elijah Hall
# Mr. Raymond Stone
# John Dickerson MD
# Mr. Alex Franklin
#  Jessica Dunn
# Mr. Michael Stevenson
# Jason Jones DDS
# Adriana Wade MD
# Erica Hurley MD
# Dr. Garrett Wright
# Mr. James Allen
# Mr. Timothy Harper MD
# Dale Brown MD
# Dr. Christina Moore
# Angela Peterson MD
# Jennifer Ferguson MD
# ...

# %% [raw]
# #import dependencies  PREFIXES
# import pandas as pd
#
# student_data_to_load = "Resources/students_complete.csv"
#
# student_data_df = pd.read_csv(student_data_to_load)
# student_data_df.head()
#
#
# # Add each prefix and suffix to remove to a list.
# prefixes_suffixes = ["Dr. ", "Mr. ","Ms. ", "Mrs. ", "Miss ", " MD", " DDS", " DVM", " PhD"]
# # Iterate through the "prefixes_suffixes" list and replace them with an empty space, "" when it appears in the student's name.
# for word in prefixes_suffixes:
#     student_data_df["student_name"] = student_data_df["student_name"].str.replace(word,"")
#
# student_data_df.head(10)
#
# # we need to get the cleaned students' names in a separate file so we don't affect the DataFrame.
# # Put the student names in a list.
# student_names = student_data_df["student_name"].tolist()
# student_names
#
# ##Now, add all the students' names that are greater than or equal to 3 to a list.
# # Create a new list and use it for the for loop to iterate through the list.
# students_fixed = []
#
# ###Use an if statement to check the length of the name.
#
# # If the name is greater than or equal to 3, add the name to the list.
#
# for name in student_names:
#     if len(name.split()) >= 3:
#         students_fixed.append(name)
#
# # Get the length of the students' names that are greater than or equal to 3.
# len(students_fixed)
